# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import cobra
from MatplotProp import CanvasStyle, PltProps
PltProps()

# %%
# all_slope = pd.read_csv('FlyDFA_slope.csv')
t_points = [0, 1, 2, 3, 4, 5, 6, 8, 10, 12, 14, 16, 18]
files = ['Proteome_CFR/Fly_Proteome_{}.csv'.format(t) for t in t_points]

data = pd.read_csv(files[0])
res = np.zeros((len(data), len(t_points)))
names = []
for i, file in enumerate(files):
    data = pd.read_csv(file)
    for j in range(data.shape[0]):
        row = data.iloc[j]
        read = str(row.values[0]).split(";")
        if i==0:
            names.append(read[0])
        res[j, i] = read[1]
            
df = pd.DataFrame(data=res)
df.columns = t_points
df.index = names

# %%
df
# Out:
#                0         1         2         3         4         5         6   \
# CBPS     0.000000  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# ABTA     0.088057  0.088057  0.088057  0.088057  0.088057  0.088057  0.088057
# AGT_1    0.000000  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# ATCase   0.000000  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# ADSS     0.000129  0.000129  0.000129  0.000129  0.000129  0.000129  0.000129
# ...           ...       ...       ...       ...       ...       ...       ...
# FAAA     0.196332  0.196332  0.196332  0.196332  0.196332  0.196332  0.196332
# HGO      0.196332  0.196332  0.196332  0.196332  0.196332  0.196332  0.196332
# HPPD     0.196332  0.196332  0.196332  0.196332  0.196332  0.196332  0.196332
# MAAI     0.196332  0.196332  0.196332  0.196332  0.196332  0.196332  0.196332
# AACCOAT  0.196332  0.196332  0.196332  0.196332  0.196332  0.196332  0.196332
#
# ...

# %%
fig = plt.figure(figsize=(13, 8))
ax = fig.add_subplot(111)
sns.heatmap(df)

# %%
# all_slope = pd.read_csv('FlyDFA_slope.csv')
t_points = [0, 4, 10]
files = ['Proteome_CFR/Fly_RPKM_Proteome_{}.csv'.format(t) for t in t_points]

data = pd.read_csv(files[0])
res = np.zeros((len(data), len(t_points)))
names = []
for i, file in enumerate(files):
    data = pd.read_csv(file)
    for j in range(data.shape[0]):
        row = data.iloc[j]
        read = str(row.values[0]).split(";")
        if i==0:
            names.append(read[0])
        res[j, i] = read[1]
            
df = pd.DataFrame(data=res)
df.columns = t_points
df.index = names

# %%
df
# Out:
#                0         4         10
# CBPS     0.000000  0.000000  0.000000
# ABTA     0.088057  0.088057  0.088057
# AGT_1    0.000000  0.000000  0.000000
# ATCase   0.000000  0.000000  0.000000
# ADSS     0.000129  0.000129  0.000129
# ...           ...       ...       ...
# FAAA     0.196332  0.196332  0.196332
# HGO      0.196332  0.196332  0.196332
# HPPD     0.196332  0.196332  0.196332
# MAAI     0.196332  0.196332  0.196332
# AACCOAT  0.196332  0.196332  0.196332
#
# [363 rows x 3 columns]

# %%
fig = plt.figure(figsize=(13, 8))
ax = fig.add_subplot(111)
sns.heatmap(df)

# %%
stemcell = cobra.io.load_matlab_model('model_MGSA.mat')

# %%
for i, ele in enumerate(stemcell.reactions):
    if i<50 and len(ele.gene_reaction_rule)>0:
        print(i, ":", ele.name, '-->',ele.gene_reaction_rule, '<--')
        print('==========================================================')
# Out:
# 12 :  1,3-Diaminopropane:oxygen oxidoreductase (deaminating) --> (8639.1) or (26.1) or (314.2) or (314.1) <--
# ...
# 24 :  24R-Vitamin D-25-hydroxylase (D2) --> (1591.1) <--
# ...
# 25 :  24R-Vitamin D-25-hydroxylase (D3) --> (1591.1) <--
# ...
# 34 :  1-alpha-Vitamin D-25-hydroxylase (D2) --> (1594.1) <--
# ...
# 35 :  1-alpha-Vitamin D-25-hydroxylase (D3) --> (1594.1) <--
# ...
# 38 : L-2-aminoadipate shuttle (cytosol/mitochondria) --> (89874.1) <--
# ...
# 40 :  2-Hydroxybutyrate:NAD+ oxidoreductase --> (92483.1) or (3948.2) or (55293.1) or (3945.1 and 3939.1) or (3939.1) or (160287.1) or (3945.1) or (3948.1) <--
# ...
# 41 :  2-hydroxybutyrate cotransport with proton --> (6566.1) or (9123.1) or (9194.1) <--
# ...
# 42 : bicarbonate transport (Na/HCO3 1:2 cotransport) --> (57835.3) or (8671.1) or (57835.2) or (57835.1) or (57835.4) <--
# ...
